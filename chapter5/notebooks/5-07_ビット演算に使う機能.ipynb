# %% [markdown]
# ## 5.7 ビット演算に使う機能

# %% [markdown]
# ### 各ipynbファイル共通の初期設定

# %% [markdown]
# 最初に以下を実行してください。

# %%
# !git clone --filter=blob:none --sparse https://github.com/editor-kagaku/Binary.git
# %cd Binary
# !git sparse-checkout set chapter5
# %cd chapter5
# !pip install binary-refinery

# %% [markdown]
# もしBinary Refineryのインストール時に"error: externally-managed-environment"のエラーになった場合はこちらを実行してください。

# %%
# !pip install --break-system-packages binary-refinery

# %% [markdown]
# ### 5.7.1 可算と減算

# %%
# !emit h:0011223344556677 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: 00 11 22 33 44 55 66 77                          .."3DUfw
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | add 8 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: 08 19 2A 3B 4C 5D 6E 7F                          ..*;L]n.
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | sub 8 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: F8 09 1A 2B 3C 4D 5E 6F                          ...+<M^o
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | add h:11223344 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: 11 33 55 77 55 77 99 BB                          .3UwUw..
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | add 0x44332211 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: 11 33 55 77 55 77 99 BB                          .3UwUw..
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | sub h:11223344 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: EF EF EF EF 33 33 33 33                          ....3333
# --------------------------------------------------------------------

# %%
# !emit h:0011223344556677 | sub 0x44332211 | peek -W 16 -r
# Out:
# --------------------------------------------------------------------
# 0: EF EE EE EE 33 33 33 33                          ....3333
# --------------------------------------------------------------------

# %% [markdown]
# ### 5.7.2 addコマンドとsubコマンドの機能を使ったPythonスクリプト

# %%
# !python3 add-sub.py
# Out:
# Original data:
# --------------------------------------------------------------------
# 0: 00 11 22 33 44 55 66 77                          .."3DUfw
# --------------------------------------------------------------------
#
# add 8:
# --------------------------------------------------------------------
# 0: 08 19 2A 3B 4C 5D 6E 7F                          ..*;L]n.
# --------------------------------------------------------------------
#
# sub 8:
# --------------------------------------------------------------------
# 0: F8 09 1A 2B 3C 4D 5E 6F                          ...+<M^o
# --------------------------------------------------------------------
#
# add h:11223344:
# --------------------------------------------------------------------
# 0: 11 33 55 77 55 77 99 BB                          .3UwUw..
# --------------------------------------------------------------------
#
# add 0x44332211:
# --------------------------------------------------------------------
# ...

# %% [markdown]
# ### 5.7.3 ビットの反転、ローテート、シフト

# %%
# !emit 11001001 | pack 2 | neg | pack -R 2 -w 8
# Out:
# 00110110

# %%
# !emit 11001001 | pack 2 | rotl 3 | pack -R 2 -w 8
# Out:
# 01001110

# %%
# !emit 11001001 | pack 2 | rotr 4 | pack -R 2 -w 8
# Out:
# 10011100

# %%
# !emit 11001001 | pack 2 | shl 3 | pack -R 2 -w 8
# Out:
# 01001000

# %%
# !emit 11001001 | pack 2 | shr 4 | pack -R 2 -w 8
# Out:
# 00001100

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | rotl 5 | pack -R 2 -w 8
# Out:
# 00010000
# 00000010
# 00000001
# 00100000

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | rotl -B 2 5 | pack -R 2 -w 8
# Out:
# 00000010
# 00010000
# 00000000
# 00100001

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | rotl -E -B 2 5 | pack -R 2 -w 8
# Out:
# 00000010
# 00010000
# 00000000
# 00100001

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | shl 5 | pack -R 2 -w 8
# Out:
# 00000000
# 00000000
# 00000000
# 00100000

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | shl -B 2 5 | pack -R 2 -w 8
# Out:
# 00000000
# 00010000
# 00000000
# 00100001

# %%
# !emit 10000000 00010000 00001000 00000001 | pack 2 | shl -E -B 2 5 | pack -R 2 -w 8
# Out:
# 00000010
# 00000000
# 00000000
# 00100000

# %% [markdown]
# ### 5.7.4 negコマンド等の機能を使ったPythonスクリプト

# %%
# !python3 negate-rotate-shift.py
# Out:
# Original data:
# 11001001
#
# neg:
# 00110110
#
# rotl 3:
# 01001110
#
# rotr 4:
# 10011100
#
# shl 3:
# 01001000
#
# shr 4:
# 00001100
