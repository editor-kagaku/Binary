# %% [markdown]
# ## 5.10 圧縮関係の機能

# %% [markdown]
# ### 各ipynbファイル共通の初期設定

# %% [markdown]
# 最初に以下を実行してください。

# %%
# !git clone https://github.com/editor-kagaku/Binary.git
# %cd Binary/chapter5
# !pip install binary-refinery

# %% [markdown]
# もしBinary Refineryのインストール時に"error: externally-managed-environment"のエラーになった場合はこちらを実行してください。

# %%
# !pip install --break-system-packages binary-refinery

# %% [markdown]
# ### 5.10.1 zlibで圧縮されたデータの展開

# %%
# !emit h:11 | stretch 96 | zl -R -g | dump 11.bin.gz
# !gzip -cd 11.bin.gz | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !gzip -cd 11.bin.gz | peek -W 16 -E
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 10: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 20: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 30: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 40: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !ef 11.bin.gz | zl | peek -W 16 -E
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 10: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 20: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 30: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 40: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %% [markdown]
# ### 5.10.2 LZMAで圧縮されたデータの展開

# %%
# !emit h:11 | stretch 96 | lzma -R -r | peek -W 16
# Out:
# --------------------------------------------------------------------
# 00.014 kB; 30.05% entropy; data
# --------------------------------------------------------------------
# 0: E0 00 5F 00 06 5D 00 08 EE 96 00 00 00 00        .._..]........
# --------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.068 kB; 57.86% entropy; XZ compressed data, checksum CRC64
# ---------------------------------------------------------------------
# 00: FD 37 7A 58 5A 00 00 04 E6 D6 B4 46 02 00 21 01  .7zXZ......F..!.
# 10: 1C 00 00 00 10 CF 58 CC E0 00 5F 00 06 5D 00 08  ......X..._..]..
# 20: EE 96 00 00 00 00 00 00 8B 10 54 B1 74 40 C8 BB  ..........T.t@..
# 30: 00 01 22 60 53 92 86 CA 1F B6 F3 7D 01 00 00 00  .."`S......}....
# 40: 00 04 59 5A                                      ..YZ
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -x | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.068 kB; 57.86% entropy; XZ compressed data, checksum CRC64
# ---------------------------------------------------------------------
# 00: FD 37 7A 58 5A 00 00 04 E6 D6 B4 46 02 00 21 01  .7zXZ......F..!.
# 10: 1C 00 00 00 10 CF 58 CC E0 00 5F 00 06 5D 00 08  ......X..._..]..
# 20: EE 96 00 00 00 00 00 00 8B 10 54 B1 74 40 C8 BB  ..........T.t@..
# 30: 00 01 22 60 53 92 86 CA 1F B6 F3 7D 01 00 00 00  .."`S......}....
# 40: 00 04 59 5A                                      ..YZ
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -a | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.026 kB; 28.63% entropy; LZMA compressed data, streamed
# ---------------------------------------------------------------------
# 00: 5D 00 00 00 04 FF FF FF FF FF FF FF FF 00 08 EE  ]...............
# 10: 97 07 FF FF FF FF 80 00 00 00                    ..........
# ---------------------------------------------------------------------

# %% [markdown]
# ### 5.10.3 様々な圧縮アルゴリズムによる圧縮データの自動展開

# %%
# !emit h:11 | stretch 96 | zl -R | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | zl -R -z | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | zl -R -g | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -r | decompress | peek -W 16
# Out:
# --------------------------------------------------------------------
# 00.014 kB; 30.05% entropy; data
# --------------------------------------------------------------------
# 0: E0 00 5F 00 06 5D 00 08 EE 96 00 00 00 00        .._..]........
# --------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -x | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -a | decompress | peek -W 16
# Out:
# ---------------------------------------------------------------------
# 00.096 kB; 00.00% entropy; data
# ---------------------------------------------------------------------
# 00: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ..:                    4 repetitions
# 50: 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11  ................
# ---------------------------------------------------------------------

# %%
# !emit h:11 | stretch 96 | lzma -R -r | decompress -P | peek -W 16
# Out:
# (20:12:05) warning in decompress: no compression engine worked, returning original data.
# --------------------------------------------------------------------
# 00.014 kB; 30.05% entropy; data
# --------------------------------------------------------------------
# 0: E0 00 5F 00 06 5D 00 08 EE 96 00 00 00 00        .._..]........
# --------------------------------------------------------------------

# %% [markdown]
# ### 5.10.4 decompressコマンドの機能を使ったPythonスクリプト

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !gzip -c /etc/os-release > os-release.gz
# !bzip2 -c /etc/os-release > os-release.bz2
# !xz -c /etc/os-release > os-release.xz
# !python3 decompress.py -h
# Out:
# usage: decompress.py [-h] filepath
#
# positional arguments:
#   filepath    圧縮ファイルのパス
#
# options:
#   -h, --help  show this help message and exit

# %%
# !python3 decompress.py os-release.gz
# Out:
# Type: gzip compressed data, was "os-release", last modified: Wed Aug  2 13:14:26 2023, from Unix
# os-releaseにファイルを展開しました。

# %%
# !cat os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !rm os-release
# !python3 decompress.py os-release.bz2
# Out:
# Type: bzip2 compressed data, block size = 900k
# os-releaseにファイルを展開しました。

# %%
# !cat os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !rm os-release
# !python3 decompress.py os-release.xz
# Out:
# Type: XZ compressed data, checksum CRC64
# os-releaseにファイルを展開しました。

# %%
# !cat os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
